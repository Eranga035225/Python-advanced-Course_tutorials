# %% [markdown]
# ## 5 Functions
#
# A function is a block of organized, reusable code that is used to perform a single, related action. Functions provide better modularity for your application and a high degree of code reusing.
#
# As you already know, Python gives you many built-in functions like print(), etc. but you can also create your own functions. These functions are called user-defined functions.
#
# Defining a Function
# You can define functions to provide the required functionality. Here are simple rules to define a function in Python.
#
# 1. Function blocks begin with the keyword def followed by the function name and parentheses ( ( ) ).
#
# 2. Any input parameters or arguments should be placed within these parentheses. You can also define parameters inside these parentheses.
#
# 3. The first statement of a function can be an optional statement - the documentation string of the function or docstring.
#
# 4. The code block within every function starts with a colon (:) and is indented.
#
# 5. The statement return [expression] exits a function, optionally passing back an expression to the caller. A return statement with no arguments is the same as return None.
#
#
# <img src="files/5 Functions.png">

# %%
def func1():
    
    print("This is my Function!")
    print("**********************")

# %%
func1()
# Out:
# This is my Function!
# **********************

# %%
func1()
# Out:
# This is my Function!
# **********************

# %%
def myFunc(a,b,c):
    
    print('a:',a)
    print('b:',b)
    print('c:',c)

# %%
myFunc(10,'Hello',20.5)
# Out:
# a: 10
# b: Hello
# c: 20.5

# %%
myFunc(20,'World',60.2)
# Out:
# a: 20
# b: World
# c: 60.2

# %%
myFunc(50,10,40)
# Out:
# a: 50
# b: 10
# c: 40

# %%
def calAvg(a):
    avg=sum(a)/len(a)
    print('avg:',avg)

# %%
array=[432,64,75,34,6,345,7,457,4,754,643,75,436,754,37,86,90870,34,23441]
calAvg(array)
# Out:
# avg: 6239.684210526316

# %% [markdown]
# ### Function Arguments
# You can call a function by using the following types of formal arguments −
#
# 1. Required arguments
# 2. Keyword arguments
# 3. Default arguments
# 4. Variable-length arguments

# %% [markdown]
# #### Required Arguments
# Required arguments are the arguments passed to a function in correct positional order. Here, the number of arguments in the function call should match exactly with the function definition.

# %%
def myFunc(a,b,c):
    
    print('a:',a)
    print('b:',b)
    print('c:',c)

# %%
myFunc(10,'Hellow',21.59)
# Out:
# a: 10
# b: Hellow
# c: 21.59

# %%
myFunc(10,'Hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 myFunc(10,'Hello')
#
# TypeError: myFunc() missing 1 required positional argument: 'c'

# %%
myFunc(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 myFunc(10)
#
# TypeError: myFunc() missing 2 required positional arguments: 'b' and 'c'

# %% [markdown]
# ### Default Arguments
# A default argument is an argument that assumes a default value if a value is not provided in the function call for that argument.

# %%
def myFunc(a=0,b="X",c=1000):
    
    print('a:',a)
    print('b:',b)
    print('c:',c)

# %%
myFunc(b=10,c="Hello",a=10.2)
# Out:
# a: 10.2
# b: 10
# c: Hello

# %%
myFunc(10,'Hello')
# Out:
# a: 10
# b: Hello
# c: 1000

# %%
myFunc(10)
# Out:
# a: 10
# b: X
# c: 1000

# %%
myFunc()
# Out:
# a: 0
# b: X
# c: 1000

# %%
myFunc(10,'Hello')
# Out:
# a: 10
# b: Hello
# c: 1000

# %% [markdown]
# #### Keyword Arguments
# Keyword arguments are related to the function calls. When you use keyword arguments in a function call, the caller identifies the arguments by the parameter name.
#
# This allows you to skip arguments or place them out of order because the Python interpreter is able to use the keywords provided to match the values with parameters

# %%
def myFunc(a,b,c):
    
    print('a:',a)
    print('b:',b)
    print('c:',c)

# %%
myFunc(10,"Hello",10.2)
# Out:
# a: 10
# b: Hello
# c: 10.2

# %%
myFunc(c=10.56,a=100,b="HELLO")
# Out:
# a: 100
# b: HELLO
# c: 10.56

# %%
myFunc(c=10.56,a=100)

# %%
def myFunc(a=0,b="X",c=1000):
    
    print('a:',a)
    print('b:',b)
    print('c:',c)

# %%
myFunc(b=100,a=90)

# %% [markdown]
# ### Variable-length Arguments
# You may need to process a function for more arguments than you specified while defining the function. These arguments are called variable-length arguments and are not named in the function definition, unlike required and default arguments.
# An asterisk (*) is placed before the variable name that holds the values of all nonkeyword variable arguments. This tuple remains empty if no additional arguments are specified during the function call

# %%
def myFunc(*a):
    print(a)

# %%
val=calculator(10,2)
print(val)
# Out:
# 8

# %%
myFunc(2,436,634,74,3,46,34,745,43)
# Out:
# (2, 436, 634, 74, 3, 46, 34, 745, 43)

# %%
myFunc(2,436,"Hello",74,3,46,34,745,43)
# Out:
# (2, 436, 'Hello', 74, 3, 46, 34, 745, 43)

# %%
def findAvg(*vals):
    print(vals)
    avg=sum(vals)/len(vals)
    print("Average:",avg)

# %%
findAvg(143,646,346,45,7523,34,53,234,53,2,3242,56,32,5,3,5,64,73,357,3,73)
# Out:
# (143, 646, 346, 45, 7523, 34, 53, 234, 53, 2, 3242, 56, 32, 5, 3, 5, 64, 73, 357, 3, 73)
# Average: 618.6666666666666

# %% [markdown]
# ### The return Statement
# The statement return [expression] exits a function, optionally passing back an expression to the caller. A return statement with no arguments is the same as return None.

# %% [markdown]
# <img src="files/5.1 Functions.png">

# %%
def add( arg1, arg2 ):
    
    total = arg1 + arg2
    
    return total

# %%
val = add( 10, 20 )
print ("Outside the function : ", val )
# Out:
# Outside the function :  30

# %% [markdown]
# #### Python Functions can return multiple values.
#
# When a Python Function has multiple returns, those are returned to a tuple

# %%
def calculator(val1,val2):
    
    add=val1+val2
    sub=val1-val2
    mult=val1*val2
    div=val1/val2
    
    return sub

# %%
val=calculator(10,2)
print(val)
# Out:
# 8

# %%
def calculator(val1,val2):
    
    add=val1+val2
    sub=val1-val2
    mult=val1*val2
    div=val1/val2
    
    return add,sub,mult,div

# %%
### val=calculator(10,2)
print(val)
val1=val[3]
print(val1)
# Out:
# (12, 8, 20, 5.0)
# 5.0

# %%
a,b,c,d=calculator(10,2)
print(a)
print(b)
print(c)
print(d)
# Out:
# 12
# 8
# 20
# 5.0

# %% [markdown]
# ### The Anonymous Functions
# These functions are called anonymous because they are not declared in the standard manner by using the def keyword. You can use the lambda keyword to create small anonymous functions.
#
# 1. Lambda forms can take any number of arguments but return just one value in the form of an expression. They cannot contain commands or multiple expressions.
#
# 2. An anonymous function cannot be a direct call to print because lambda requires an expression.
#
# 3. Lambda functions have their own local namespace and cannot access variables other than those in their parameter list and those in the global namespace.

# %%
def myFunc(arg1,arg2):
    return arg1+arg2

# %%
myFunc = lambda arg1,arg2:arg1+arg2

# %%
val1=myFunc(10,20)
val2=myFunc(20,20)

print ("Value of total : ",val1)
print ("Value of total : ",val2)
# Out:
# Value of total :  30
# Value of total :  40

# %%
myFunc = lambda arg1,arg2,*arg3:(arg1+arg2)*arg3

val=myFunc(2,3,2,7)
print(val)
# Out:
# (2, 7, 2, 7, 2, 7, 2, 7, 2, 7)

# %%
def myFunc2(a,b,c,d):
    
    myFunc = lambda arg1,arg2,arg3:arg1+arg2+arg3
    
    print(myFunc(a,b,c))

# %%
myFunc2(10,20,30,40)
# Out:
# 60

# %%
def power(val):
    return val*val

# %%
a=power(5)
print(a)
# Out:
# 25

# %%
values=[4,5,6,2,1,5,2,5]

a=map(power,values)
print(list(a))
# Out:
# [16, 25, 36, 4, 1, 25, 4, 25]

# %%
values=[4,5,6,2,1,5,2,5]

a=[power(values[i]) for i in range(len(values))]
print(a)
# Out:
# [16, 25, 36, 4, 1, 25, 4, 25]

# %% [markdown]
# ### Scope of Variables
# All variables in a program may not be accessible at all locations in that program. This depends on where you have declared a variable.
#
# The scope of a variable determines the portion of the program where you can access a particular identifier. There are two basic scopes of variables in Python
#
# 1. Global variables
# 2. Local variables
#
# ### Global vs. Local variables
# Variables that are defined inside a function body have a local scope, and those defined outside have a global scope.
#
# This means that local variables can be accessed only inside the function in which they are declared, whereas global variables can be accessed throughout the program body by all functions. When you call a function, the variables declared inside it are brought into scope

# %%
total = 0   # This is global variable.
# Function definition is here
def add( arg1, arg2 ):
   # Add both the parameters and return them."
    total = arg1 + arg2; # Here total is local variable.
    print ("Inside the function local total : ", total)
    return total

# Now you can call sum function
val=add( 10, 20 )
print ("Outside the function global total : ", total )
